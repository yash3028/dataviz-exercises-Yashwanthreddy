# %% [markdown]
# # 🐍 Python For Data Analysis & Visualization
# ## Course Overview — Winter 2026
#
# *© 2026 Dr. Dina Deifallah*

# %% [markdown]
# ---
# ## 🛠 Tools & Setup
#
# Before the first session, make sure you have the following ready:
#
# | Tool | Purpose | Link |
# |---|---|---|
# | **Anaconda** | Python environment + Jupyter | [Download](https://www.anaconda.com/download) |
# | *(Alternative)* **Google Colab** | Browser-based Python — no install needed | [colab.research.google.com](https://colab.research.google.com) |
# | **GitHub account** | Version control + exercise submission | [github.com](https://github.com) |
# | **Streamlit Community account** | Deploy interactive dashboards online | [share.streamlit.io](https://share.streamlit.io) |
# | **Claude/ any LLM** | AI coding assistant throughout the course | [claude.ai](https://claude.ai/new) |
# | **Teams** | Course communication |  |

# %% [markdown]
# ---
# ## 📐 Lecture Structure
#
# Every session follows the same rhythm:
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │  15 mins  │  Model Answer Review (previous week exercise)       │
# │  60 mins  │  New Material (theory + coding examples)            │
# │  15 mins  │  ☕ Break                                            │
# │  45 mins  │  Class Exercise (hands-on coding)                   │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# **Class Exercise rules:**
# - Working with colleagues is actively encouraged 🤝
# - The exercise notebook must be pushed to **your own GitHub repo** before leaving the classroom
# - Each week, class material + model answer of previous week class exercise are pushed to the class-material repo right before the start of the lecture

# %% [markdown]
# ---
# ## 🗂 GitHub Repository Structure
#
# We use two separate GitHub repositories:
#
# ### 📚 Class-Material Repo (instructor → you)
# - Contains lecture notes, datasets, and model answers
# - You **PULL** from this repo at the start of each lecture
# - You **NEVER PUSH** to this repo — it is read-only for students
#
# ```bash
# # First time — clone the class repo
# git clone https://github.com/dina-deifallah/data-viz-class-material.git
#
# # Every lecture — update your local copy
# git pull
# ```
#
# ### 📤 Your Personal Exercise Repo (you → world)
# - You create this yourself as a **public** GitHub repository
# - Each week: complete the exercise, push before leaving class
# - Name it as follows --> `dataviz-exercises-yourname`
#
# ```bash
# # Push your exercise at the end of each lecture
# git add weekxx/
# git commit -m "Lecture xx exercise"
# git push
# ```
#
# > ⚠️ **PULL from the class repo. PUSH to your own repo. Never the reverse**
#
# ### Folder structure (your personal repo)
#
# ```
# dataviz-exercises-yourname/
#   week01/
#     lecture01_exercise.ipynb      ← Part 1 lectures
#   week02/
#     lecture02_exercise.ipynb
#   ...
#   week09/
#     lecture09_exercise.py         ← Part 2 lectures (Streamlit .py files)
#   week10/
#     lecture10_exercise.py
#   ...
# ```

# %% [markdown]
# ---
# ## 📕 Course Contents
#
# The course is divided into two parts.
#
# ---
#
# ### Part I — Interactive Data Visualization with Plotly 📊
# *(Lectures 1–8)*
#
# We move from exploratory charts to professional, explanatory visualizations — applying design principles from *Storytelling with Data* (Knaflic) throughout.
#
# | Lecture | Topic | Chart Types | Dataset |
# |---|---|---|---|
# | L1 | Course intro + Plotly basics | — | Stocks (built-in) |
# | L2 | Bar charts & design principles | Bar, horizontal bar, stacked | World Happiness Report |
# | L3 | Line charts & slopegraphs | Line, slopegraph | CO₂ Emissions |
# | L4 | Scatter & bubble charts | Scatter, bubble | Gapminder |
# | L5 | Distribution charts | Histogram, box, violin | Airbnb London |
# | L6 | Hierarchical charts | Treemap, sunburst | Global Energy Mix |
# | L7 | Heatmaps & waterfall charts | Heatmap, waterfall | Netflix Catalogue |
# | L8 | Choropleth maps + full story | Choropleth, multi-chart story | World Development |
#
# **Part I learning outcomes:**
# - Apply SWD chart-selection and design principles to real datasets
# - Build professionally styled, insight-driven Plotly charts
# - Use grey-and-highlight colour technique, zero baseline, insight titles
# - Structure a multi-chart narrative
#
# ---
#
# ### Part II — Building Interactive Dashboards with Streamlit 🚀
# *(Lectures 9–14)*
#
# We take the charts from Part I and turn them into multi-page, filterable, deployable dashboards — applying design principles from *The Big Book of Dashboards* (Wexler, Shaffer & Cotgreave).
#
# | Lecture | Topic | Key Skills |
# |---|---|---|
# | L9  | Streamlit foundations | `st.metric`, `st.columns`, `st.sidebar`, `st.plotly_chart`, deploy |
# | L10 | Filters & interactivity | `st.selectbox`, `st.multiselect`, `st.slider`, `st.date_input`, chained filters |
# | L11 | Multi-page apps | `st.navigation`, `pages/`, `utils.py`, `st.session_state`, `st.tabs` |
# | L12 | Design & polish | Custom CSS, `@st.cache_data`, BBD colour rules, 5-second test |
# | L13 | Capstone build session | Guided in-class dashboard build  |
# | L14 | Open Q&A | final questions on course material & final project  |
#
# **Part II learning outcomes:**
# - Build multi-page Streamlit dashboards from scratch
# - Apply BBD filter design, colour taxonomy (sequential/diverging/categorical/highlight)
# - Handle CVD accessibility (blue-orange instead of red-green)
# - Deploy a working dashboard to Streamlit Community Cloud
# - Present a data product with a clear Big Idea and audience

# %% [markdown]
# ---
# ## ✅ Grading
#
# | Component | Weight | Details |
# |---|---|---|
# | **Class Exercises / Participation** | 30% | Weekly exercise notebooks/python files pushed to your GitHub repo |
# | **Final Project** | 70% | Individual - in-depth data analysis + multi-page published Streamlit dashboard|
#
# ### Class Exercises (30%)
# - One exercise per lecture (Lectures 2–13)
# - Pushed to your public GitHub repo by end of class
# - Graded on: correct output, code quality, discussed design principles applied
# - Model answers reviewed at the start of the following lecture
#
# ### Final Project (70%)
# An in-depth analysis of a real-world data set of your choice + multi-page published Streamlit dashboard. All details including deliverables + grading criteria will be published 6 weeks before submission deadline. **Submission Deadline: Friday 17-07-2026**

# %% [markdown]
# ---
# ## 📚 Additional Resources
#
# ### Python & Data Analysis
# 1. [Learning Python: Powerful Object-Oriented Programming](https://www.oreilly.com/library/view/learning-python-5th/9781449355722/) — Lutz
# 2. [Python For Data Analysis](https://wesmckinney.com/book/) — McKinney (Pandas, NumPy, IPython)
# 3. [Data Manipulation with Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/) *(in Python Data Science Handbook — open source)*
# 4. [Automate the Boring Stuff with Python](https://automatetheboringstuff.com/) *(open source)*
# 5. [Python for Everybody](https://www.py4e.com/) *(open source)*
#
# ### Data Visualization
# 6. [Fundamentals of Data Visualization](https://clauswilke.com/dataviz/) — Wilke *(open source)*
# 7. *Storytelling with Data* — Knaflic *(course textbook, Part I)*
# 8. *The Big Book of Dashboards* — Wexler, Shaffer & Cotgreave *(course textbook, Part II)*
#
# ### Tools
# 9. [Plotly Official Documentation](https://plotly.com/python/)
# 10. [Streamlit Documentation](https://docs.streamlit.io)
# 11. [Real Python](https://realpython.com) — tutorials and deep-dives

# %% [markdown]
# ---
#
# > *This course is about learning to communicate with data — not just analyse it.*
# > *Every chart you build should answer a specific question for a specific audience.*
